# %%
try:
    age=int(input("Enter age"))
    print(age)
except:
    print("Invalid age")
# Out:
# Invalid age

# %%
try:
    age=int(inp("Enter age"))
    print(age)
except ValueError:
    print("Invalid age")
except SyntaxError:
    print("Invalid Syntax")
except NameError:
    print("Invalid Function name")
# Out:
# Invalid Function name

# %%
try:
    print("Process")
except:
    print("error")
finally:
    print("completed")
# Out:
# Process
# completed

# %%
try:
    o=open("file.csv","r")
except FileNotFoundError:
    print("File not available in your system")
finally:
    print("file opened")
# Out:
# File not available in your system
# file opened

# %%
try:
    age=int(input("Enter age"))
    print(age)
except:
    print("Invalid age")
