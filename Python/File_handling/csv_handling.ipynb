# %%
import  csv
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\file.csv","r")as file:
 reader=csv.reader(file)
 for row in reader:
     print(row)

# %%
import  csv
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\file.csv","w")as file:
 writer=csv.writer(file)
 writer.writerow(["Monitor",25000])
 writer.writerow(["CPU",36000])

# %%
import csv 
data=[
    ['Product', 'Sales'],
    ['Mobile', '59000'],
    ['Charger', '18000'],
    ['Charging cable', '6000'],
    ['Mouse', '600'],
    ["Monitor",25000],
    ["CPU",36000]
    ]
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\file.csv","w",newline="")as file:
    writer=csv.writer(file)
    writer.writerows(data)

# %%
import csv
total_sales=0
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\file.csv","r")as file:
    reader=csv.DictReader(file)
    for row in reader:
        total_sales=total_sales+int(row['Sales'])
        print(total_sales)
# Out:
# 59000
# 77000
# 83000
# 83600
# 108600
# 144600
