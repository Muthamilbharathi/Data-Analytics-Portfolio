# %%
file=open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\text.txt","r")
data=file.read()
print(data)
file.close()  #for multi line command use '''.

# %%
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\text.   txt","r") as file:
   data=file.read()
print(data)

# %%
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\text.txt","r") as about:
    for line in about:
        print(line)

# %%
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\text.txt","a") as about:
    about.write("This is the history of DPI")
    print(about)

# %%
with open(r"C:\Users\ELCOT\Documents\Portfolio\Data-Analytics-Portfolio\Python\File_handling\text.txt","w")as file:
    file.write("MB")
print(file)
