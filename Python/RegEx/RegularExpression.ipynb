# %%
import re 
text="Python is easy"
res=re.search('is',text)
print(res)
# Out:
# <re.Match object; span=(7, 9), match='is'>

# %%
import re 
text="Python is easy"
res=re.findall('is',text)
print(res)
# Out:
# ['is']

# %%
import re
text="Power BI"
res=re.sub('Power BI','PowerBI',text)
print(res)
# Out:
# PowerBI

# %%
import re
a="order123"
data=re.findall('\\d',a)
print(data)
# Out:
# ['1', '2', '3']

# %%
import re
a="order123"
data=re.findall('[a-z]',a) #a-z  finds lowercase,A-Z finds uppercase
print(data)
# Out:
# ['o', 'r', 'd', 'e', 'r']

# %%
import re
text="sales:500 Profit:1000"
data=re.findall("\\d+",text)
print(data)
# Out:
# ['500', '1000']

# %%
import re
mailid="mb46@gmail.com"
mailid1="mb@.com"
mailid2="46.com"
data=re.findall(r"\w+@\w+.\w+",(mailid))
print(data)
# Out:
# ['mb46@gmail.com']

# %%
import re
phn="0977565433"
data=re.findall(r"\d{10}",phn)
print(data)
# Out:
# ['0977565433']
