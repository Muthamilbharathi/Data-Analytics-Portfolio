# %%
import numpy as np
calls=np.array([5,6,7,8,9,11])
print(calls)
# Out:
# [ 5  6  7  8  9 11]

# %%
#multi dimension

multi=np.array([["Jan","Feb","Mar"],
               [300,400,500],
               [600,700,800],
               [6,7,8]])
print(multi)
# Out:
# [['Jan' 'Feb' 'Mar']
#  ['300' '400' '500']
#  ['600' '700' '800']
#  ['6' '7' '8']]

# %%
multi=np.array([["Jan","Feb","Mar"],
               [300,400,500],
               [600,700,800],
               [6,7,8]])
print(multi.shape)   #   .shape gives the no.of rows and columns
# Out:
# (4, 3)

# %%
multi[1][2]
# Out:
# np.str_('500')

# %%
multi[:,2]
# Out:
# array(['Mar', '500', '800', '8'], dtype='<U21')

# %%
multi[2:,2]
# Out:
# array(['800', '8'], dtype='<U21')

# %%
multi[:,1]
# Out:
# array(['Feb', '400', '700', '7'], dtype='<U21')

# %% [markdown]
# BOOLEAN FILTERING

# %%
s_r=np.array([3.6,4,2,3,1])
s_r[s_r>3]
# Out:
# array([3.6, 4. ])

# %%
s_r[s_r>3]
# Out:
# array([3.6, 4. ])

# %%
s_r[(s_r>=2)&(s_r<=4)]
# Out:
# array([3.6, 4. , 2. , 3. ])

# %%
np.sum(calls)
# Out:
# np.int64(46)

# %%
print(np.mean(calls))
print(np.max(calls))
print(np.min(calls))
print(np.std(calls))
# Out:
# 7.666666666666667
# 11
# 5
# 1.9720265943665387

# %%
North=np.array([5,100,30])
South=np.array([3,2,5])
np.concatenate((North,South))
# Out:
# array([  5, 100,  30,   3,   2,   5])
